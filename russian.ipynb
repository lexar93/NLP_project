# %%
import xml.etree.ElementTree as et
import glob
import os
import string
from os import walk
path ="D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/" 
paths = [os.path.join(root, name)
        for root, dirs, files in os.walk(path)
             for name in files
             if name.endswith((".xml"))]

# %%
print(len(paths))
# Out:
# 137937

# %%
from lxml import etree
parser = etree.XMLParser(recover=True)


outcry = {}
body = ['' for i in range(len(paths))]
outcry['symbol'] = []
outcry['jobno']= []
outcry['dat'] = []
outcry['language'] = []
outcry['keywords'] = [[] for i in range(len(paths))]
outcry['paths'] = []
outcry['text'] = [[] for i in range(len(paths))]
for i in range(len(paths)):       

        tree = tree = et.parse(paths[i],parser=parser)
        root = tree.getroot()
        
        outcry['paths'].append(paths[i])
        
        for idno in root.findall(".//idno") or []:
            if idno.text is not None:
                outcry[idno.get('type')].append(idno.text) 
                
  
        for date in tree.findall('.//date') or []:
            if date.text is not None:
                   outcry['dat'].append(date.text) 
                    
        for lg in tree.findall('.//language')or []:
                if lg.text is not None:
                     outcry['language'].append(lg.text)
                        
        for keyword in root.find(".//keywords") or []:
               if keyword.text is not None:
                    outcry['keywords'][i].append(keyword.text)
                                
                        
        for paragraph in tree.findall(".//body/p"):
            for sentence in paragraph.findall("s"):
                if sentence.text is not None:
                    body[i] += sentence.text
                    if sentence.text[-1:] not in string.punctuation:
                        body[i] += '. '
                    elif sentence == paragraph.findall("s")[-1]:
                        #if it's the last sentence in a paragraph
                        if sentence.text[-1:] in string.punctuation:
                            #replace last element for a period
                            body[i] = body[i][:-1]
                        body[i] += '. '
                    else:
                        body[i] += ' '
                        
                    outcry['text'][i] = body[i]
# Out:
# C:\Users\AlexVaqueroRamirez\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: FutureWarning: The behavior of this method will change in future versions. Use specific 'len(elem)' or 'elem is not None' test instead.

# %%
print(len(outcry['jobno']))
# Out:
# 137937

# %%
indices = [i for i, x in enumerate(outcry['keywords']) if x == []]

# %%
print(len(indices))
# Out:
# 30049

# %%
import pandas as pd
outta = pd.DataFrame.from_dict(outcry,orient='index')
outta = outta.transpose()
outta.drop(outta.index[indices],inplace=True,)
outta = outta.reset_index(drop=True)
s = pd.Series(range(len(outta)))
outta.set_index(s,inplace=True,append = True)
outta
# Out:
#                                   symbol     jobno       dat language  \
# 0      0       TRANS/WP.29/1999/14/ADD.1  G9920254  19900202  Russian
# 1      1                       ST/AI/379  N0667367  19921029  Russian
# 2      2                      ST/SGB/253  N0667358  19921029  Russian
# 3      3                       A/47/1000  N9344927  19930813  Russian
# 4      4                       A/47/1001  N9345600  19930820  Russian
# 5      5                       A/47/1002  N9345988  19930820  Russian
# 6      6                       A/47/1003  N9346306  19930823  Russian
# 7      7                       A/47/1004  N9346993  19930826  Russian
# 8      8                       A/47/1005  N9347102  19930826  Russian
# 9      9                       A/47/1006  N9347108  19930901  Russian
# 10     10                      A/47/1007  N9347334  19930827  Russian
# 11     11                      A/47/1008  N9348299  19930902  Russian
# 12     12                      A/47/1009  N9348376  19930902  Russian
# 13     13                      A/47/1010  N9348539  19930903  Russian
# 14     14                      A/47/1011  N9348912  19930908  Russian
# 15     15                      A/47/1012  N9348926  19930915  Russian
# 16     16                      A/47/1013  N9349124  19930909  Russian
# 17     17                      A/47/1014  N9349293  19930910  Russian
# 18     18                      A/47/1015  N9349299  19930910  Russian
# 19     19                      A/47/1016  N9349820  19930914  Russian
# 20     20                      A/47/1017  N9350173  19930915  Russian
# 21     21                      A/47/1018  N9350154  19930915  Russian
# 22     22                      A/47/1019  N9350237  19930915  Russian
# 23     23                      A/47/1020  N9350450  19930916  Russian
# 24     24                      A/47/1021  N9350873  19930917  Russian
# 25     25                      A/47/1022  N9350867  19930917  Russian
# 26     26                      A/47/1023  N9351564  19930923  Russian
# 27     27                      A/47/1024  N9351039  19930920  Russian
# 28     28        A/47/7ANDADD.1-17(SUPP)  N9339581  19930101  Russian
# 29     29                       A/47/977  N9340549  19930719  Russian
# ...                                  ...       ...       ...      ...
# 107858 107858           TD/B/C.I/MEM.4/5  G1450117  20140202  Russian
# 107859 107859           TD/B/C.I/MEM.4/6  G1450571  20140501  Russian
# 107860 107860           TD/B/C.I/MEM.5/5  G1417526  20140928  Russian
# 107861 107861           TD/B/C.I/MEM.6/5  G1450283  20140309  Russian
# 107862 107862           TD/B/C.I/MEM.6/6  G1404110  20140603  Russian
# 107863 107863           TD/B/C.I/MEM.7/5  G1450454  20140421  Russian
# 107864 107864           TD/B/C.I/MEM.7/6  G1409588  20140727  Russian
# 107865 107865           TD/B/C.I/MEM.7/8  G1416183  20140914  Russian
# 107866 107866               TD/B/C.II/24  G1450162  20140216  Russian
# 107867 107867               TD/B/C.II/25  G1450153  20140213  Russian
# 107868 107868          TD/B/C.II/ISAR/70  G1410676  20140805  Russian
# 107869 107869          TD/B/C.II/ISAR/71  G1422521  20141119  Russian
# 107870 107870          TD/B/C.II/MEM.4/6  G1450377  20140403  Russian
# 107871 107871              TD/B/EX(59)/2  G1450425  20140410  Russian
# 107872 107872              TD/B/EX(59)/3  G1450400  20140407  Russian
# 107873 107873              TD/B/EX(59)/4  G1408326  20140713  Russian
# 107874 107874                TD/B/WP/260  G1450327  20140326  Russian
# 107875 107875                TD/B/WP/262  G1406632  20140624  Russian
# 107876 107876                TD/B/WP/263  G1405979  20140619  Russian
# 107877 107877                TD/B/WP/264  G1408614  20140715  Russian
# 107878 107878                TD/B/WP/265  G1416199  20140914  Russian
# 107879 107879                TD/B/WP/267  G1423855  20141208  Russian
# 107880 107880                TD/B/WP/269  G1425269  20141228  Russian
# 107881 107881          TD/B/WP/267/REV.1  G1424467  20141214  Russian
# 107882 107882           TD/B(S-XXVIII)/2  G1407230  20140702  Russian
# 107883 107883                 UNW/2014/1  N1423706  20140218     None
# 107884 107884                 UNW/2014/2  N1430669  20140422     None
# 107885 107885                 UNW/2014/3  N1429950  20140414     None
# 107886 107886                 UNW/2014/4  N1430208  20140416     None
# 107887 107887           UNW/2014/4/ADD.1  N1430215  20140416     None
#
#                                                         keywords  \
# 0      0       [MOTOR VEHICLE EQUIPMENT, ANTI-THEFT DEVICES, ...
# 1      1       [SEXUAL HARASSMENT, GRIEVANCE PROCEDURES, LABO...
# 2      2                [SEXUAL HARASSMENT, WOMEN'S ADVANCEMENT]
# 3      3       [NEGOTIATION, POLITICAL CONDITIONS, HAITI, HAI...
# 4      4       [MAPS, PEACEKEEPING OPERATIONS, CYPRUS, FINANC...
# 5      5       [FINANCING, INTERNATIONAL CRIMINAL COURTS, FOR...
# 6      6       [INTERNATIONAL CRIMINAL COURTS, JUDGES, WAR CR...
# 7      7            [PEACEKEEPING OPERATIONS, CYPRUS, FINANCING]
# 8      8                           [ELECTION OF MEMBERS, JUDGES]
# 9      9                [ELECTION OF MEMBERS, JUDGES, BIOGRAPHY]
# 10     10      [POPULATION COMPOSITION, CYPRUS, CYPRUS QUESTI...
# 11     11      [CEASEFIRES, ISRAEL, PALESTINE QUESTION, MIDDL...
# 12     12      [POLITICAL CONDITIONS, NICARAGUA, NICARAGUA SI...
# 13     13      [SANCTIONS, POLITICAL CONDITIONS, HAITI, HAITI...
# 14     14                          [INTERNATIONAL YEARS, FAMILY]
# 15     15      [HUMAN RIGHTS, RIGHT TO LIFE, DETAINED PERSONS...
# 16     16                              [FINANCING, IRAQ, KUWAIT]
# 17     17             [FINANCING, INTERNATIONAL CRIMINAL COURTS]
# 18     18      [PEACEKEEPING OPERATIONS, CYPRUS, BUDGET CONTR...
# 19     19                  [DIPLOMATIC RELATIONS, HAITI, MEXICO]
# 20     20      [PEACE TREATIES, ISRAEL, PALESTINIANS, PALESTI...
# 21     21      [PEACE TREATIES, ISRAEL, PALESTINE QUESTION, M...
# 22     22      [CEASEFIRES, ISRAEL, TERRITORIES OCCUPIED BY I...
# 23     23      [CEASEFIRES, ISRAEL, TERRITORIES OCCUPIED BY I...
# 24     24      [CEASEFIRES, ISRAEL, PALESTINE QUESTION, TERRI...
# 25     25      [STATE SUCCESSION, STATE REPRESENTATION, YUGOS...
# 26     26      [EMERGENCY RELIEF, NEGOTIATION, HUMAN RIGHTS, ...
# 27     27      [POLITICAL STATUS, WEST BANK (STATE OF PALESTI...
# 28     28      [SPECIAL MISSIONS, HAITI, CONFERENCE FACILITIE...
# 29     29      [POLITICAL STATUS, JAMMU AND KASHMIR, CEASEFIR...
# ...                                                          ...
# 107858 107858  [SERVICE INDUSTRIES, TRADE IN SERVICES, DEVELO...
# 107859 107859  [TRADE IN SERVICES, TRADE LIBERALIZATION, PHYS...
# 107860 107860  [INTERNATIONAL TRADE, MULTILATERAL TRADE NEGOT...
# 107861 107861  [ECONOMIC COOPERATION, INTERNATIONAL COOPERATI...
# 107862 107862  [ECONOMIC COOPERATION, DEVELOPMENT STRATEGIES,...
# 107863 107863  [TRADE FACILITATION, TRADE POLICY, TRADE AGREE...
# 107864 107864  [TRADE FACILITATION, TRADE POLICY, MULTILATERA...
# 107865 107865  [INTERNATIONAL TRADE, DEVELOPING ISLAND COUNTR...
# 107866 107866  [ENTREPRENEURSHIP, ENTERPRISE DEVELOPMENT, EMP...
# 107867 107867  [SCIENCE AND TECHNOLOGY POLICY, TECHNOLOGICAL ...
# 107868 107868  [ACCOUNTING AND REPORTING, CORPORATIONS, REGUL...
# 107869 107869  [ACCOUNTING AND REPORTING, STANDARDS, CORPORAT...
# 107870 107870  [INNOVATIONS, SCIENCE AND TECHNOLOGY POLICY, P...
# 107871 107871  [ECONOMIC DEVELOPMENT, ECONOMIC POLICY, TECHNI...
# 107872 107872  [MONETARY UNIONS, INTRAREGIONAL TRADE, REGIONA...
# 107873 107873  [INTERNATIONAL TRADE, ECONOMIC DEVELOPMENT, AF...
# 107874 107874  [INTERNATIONAL TRADE, COMMUNICATION POLICY, PU...
# 107875 107875  [ECONOMIC DEVELOPMENT, TECHNICAL COOPERATION, ...
# 107876 107876  [INTERNATIONAL TRADE, ECONOMIC DEVELOPMENT, TE...
# 107877 107877  [INVESTMENT PROMOTION, ENTERPRISE DEVELOPMENT,...
# 107878 107878  [ECONOMIC DEVELOPMENT, SCIENCE AND TECHNOLOGY,...
# 107879 107879  [ECONOMIC DEVELOPMENT, INTERNATIONAL TRADE, TE...
# 107880 107880  [COMMUNICATION POLICY, PUBLICATIONS, WEBSITES,...
# 107881 107881  [ECONOMIC DEVELOPMENT, INTERNATIONAL TRADE, TE...
# 107882 107882  [INTERNATIONAL TRADE, ECONOMIC DEVELOPMENT, AN...
# 107883 107883  [GENDER EQUALITY, EMPOWERMENT, WOMEN'S RIGHTS,...
# 107884 107884  [EMPOWERMENT, GENDER EQUALITY, PARTNERSHIP, PR...
# 107885 107885  [PROGRAMME EVALUATION, GENDER EQUALITY, TRUST ...
# 107886 107886                     [AUDITING, INTERNAL OVERSIGHT]
# 107887 107887                     [AUDITING, INTERNAL OVERSIGHT]
#
#                                                            paths  \
# 0      0       D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1990\trans...
# 1      1       D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1992\st\ai...
# 2      2       D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1992\st\sg...
# 3      3       D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 4      4       D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 5      5       D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 6      6       D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 7      7       D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 8      8       D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 9      9       D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 10     10      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 11     11      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 12     12      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 13     13      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 14     14      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 15     15      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 16     16      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 17     17      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 18     18      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 19     19      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 20     20      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 21     21      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 22     22      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 23     23      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 24     24      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 25     25      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 26     26      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 27     27      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 28     28      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# 29     29      D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/1993\a\47\...
# ...                                                          ...
# 107858 107858  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107859 107859  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107860 107860  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107861 107861  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107862 107862  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107863 107863  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107864 107864  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107865 107865  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107866 107866  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107867 107867  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107868 107868  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107869 107869  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107870 107870  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107871 107871  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107872 107872  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107873 107873  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107874 107874  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107875 107875  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107876 107876  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107877 107877  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107878 107878  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107879 107879  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107880 107880  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107881 107881  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b\...
# 107882 107882  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\td\b_...
# 107883 107883  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\unw\2...
# 107884 107884  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\unw\2...
# 107885 107885  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\unw\2...
# 107886 107886  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\unw\2...
# 107887 107887  D:/un_dataset/RUSSIAN/UNv1.0-TEI/ru/2014\unw\2...
#
#                                                             text
# 0      0       ОРГАНИЗАЦИЯ. ОБЪЕДИНЕННЫХ НАЦИЙ. E. ЭКОНОМИЧЕС...
# 1      1       Административная инструкция. Для сотрудников О...
# 2      2       Бюллeтень Генерального секретаря. Для сотрудни...
# 3      3       A/47/1000. S/26297. Russian. Page. Distr. GENE...
# 4      4       A/47/1001. Russian. Page. Distr. GENERAL. 20 A...
# 5      5       A/47/1002. Russian. Page. Distr. GENERAL. 20 A...
# 6      6       A/47/1003. Russian. Page. Distr. GENERAL. 23 A...
# 7      7       A/47/1004. Russian. Page. Distr. GENERAL. 26 A...
# 8      8       A/47/1005. Russian. Page. Distr. GENERAL. А/47...
# 9      9       Distr. GENERAL. А/47/1006. 1 September 1993. R...
# 10     10      A/47/1007. S/26369. Russian. Page. Distr. GENE...
# 11     11      Distr. GENERAL. A/47/1008. S/26396. RUSSIAN. O...
# 12     12      A/47/1009. S/26397. Russian. Page. Distr. GENE...
# 13     13      A/47/1010. S/26402. Russian. Page. Distr. GENE...
# 14     14      Distr. GENERAL. A/47/1011. 8 September 1993. R...
# 15     15      A/47/1012. S/26416. Russian. Page. Distr. GENE...
# 16     16      A/47/1013. Russian. Page. Distr. GENERAL. 9 Se...
# 17     17      Distr. GENERAL. A/47/1014. 10 September 1993. ...
# 18     18      Distr. GENERAL. A/47/1015. 10 September 1993. ...
# 19     19      Distr. GENERAL. A/47/1016. S/26435. 14 Septemb...
# 20     20      A/47/1017. Russian. Page. Distr. GENERAL. 15 S...
# 21     21      A/47/1018. S/26443. Russian. Page. Distr. GENE...
# 22     22      Distr. GENERAL. A/47/1019. S/26447. 15 Septemb...
# 23     23      A/47/1020. S/26453. Russian. Page. Distr. GENE...
# 24     24      Distr. GENERAL. A/47/1021. 17 September 1993. ...
# 25     25      Distr. GENERAL. A/47/1022. 17 September 1993. ...
# 26     26      Distr. GENERAL. A/47/1023. S/26471. 23 Septemb...
# 27     27      Distr. GENERAL. A/47/1024. 20 September 1993. ...
# 28     28      СОДЕРЖАНИЕ. № документа Стр. А/47/7 Первый док...
# 29     29      A/47/977. S/26112. Russian. Page. Distr. GENER...
# ...                                                          ...
# 107858 107858  Организация Объединенных Наций. TD. Конференци...
# 107859 107859  Организация Объединенных Наций. TD. Конференци...
# 107860 107860  Организация Объединенных Наций. TD. Конференци...
# 107861 107861  Организация Объединенных Наций. TD. Конференци...
# 107862 107862  Организация Объединенных Наций. TD. Конференци...
# 107863 107863  Организация Объединенных Наций. TD. Конференци...
# 107864 107864  Организация Объединенных Наций. TD. Конференци...
# 107865 107865  Организация Объединенных Наций. TD. Конференци...
# 107866 107866  Организация Объединенных Наций. TD. Конференци...
# 107867 107867  Организация Объединенных Наций. TD. Конференци...
# 107868 107868  Организация Объединенных Наций. TD. Конференци...
# 107869 107869  Организация Объединенных Наций. TD. Конференци...
# 107870 107870  Организация Объединенных Наций. TD. Конференци...
# 107871 107871  Организация Объединенных Наций. TD. Конференци...
# 107872 107872  Организация Объединенных Наций. TD. Конференци...
# 107873 107873  Организация Объединенных Наций. TD. Конференци...
# 107874 107874  Организация Объединенных Наций. TD. Конференци...
# 107875 107875  Организация Объединенных Наций. TD. Конференци...
# 107876 107876  Организация Объединенных Наций. TD. Конференци...
# 107877 107877  Организация Объединенных Наций. TD. Конференци...
# 107878 107878  Организация Объединенных Наций. TD. Конференци...
# 107879 107879  Организация Объединенных Наций. TD. Конференци...
# 107880 107880  Организация Объединенных Наций. TD. Конференци...
# 107881 107881  Организация Объединенных Наций. TD. Конференци...
# 107882 107882  Организация Объединенных Наций. TD. Конференци...
# 107883 107883  Ежегодная сессия 2014 года. 17 - 19 июня 2014 ...
# 107884 107884  Ежегодная сессия 2014 года. 17 - 19 июня 2014 ...
# 107885 107885  Ежегодная сессия 2014 года. 17 - 19 июня 2014 ...
# 107886 107886  Ежегодная сессия 2014 года. 17 - 19 июня 2014 ...
# 107887 107887  Ежегодная сессия 2014 года. 17 - 19 июня 2014 ...
#
# [107888 rows x 7 columns]

# %%
outta['language'].fillna("Russian",inplace=True)

# %%
outta.insert(5, "Category",str, True)

# %%
outta.columns
# Out:
# Index(['symbol', 'jobno', 'dat', 'language', 'keywords', 'Category', 'paths',
#        'text'],
#       dtype='object')

# %%
outta.to_csv("russian_whole.csv",index=False)

# %%
outta['Category'] = "Others"
outta["Category"][outta['keywords'].str.contains(('PEACEKEEPING OPERATIONS') , na=False,regex=False)] = "Peace"
outta["Category"][outta['keywords'].str.contains(('TROOP WITHDRAWAL') , na=False,regex=False)] = "Peace"
outta["Category"][outta['keywords'].str.contains(('NUCLEAR DISARMAMENT, ') , na=False,regex=False)] = "Nuclear"
outta["Category"][outta['keywords'].str.contains(('NUCLEAR NON-PROLIFERATION') , na=False,regex=False)] = "Nuclear"
outta["Category"][outta['keywords'].str.contains(('NUCLEAR WEAPON TESTS') , na=False,regex=False)] = "Nuclear"
outta["Category"][outta['keywords'].str.contains(('NUCLEAR WEAPONS') , na=False,regex=False)] = "Nuclear"
outta["Category"][outta['keywords'].str.contains(('DISARMAMENT NEGOTIATIONS') , na=False,regex=False)] = "Disarment"
outta["Category"][outta['keywords'].str.contains(('DISARMAMENT') , na=False,regex=False)] = "Disarment"
outta["Category"][outta['keywords'].str.contains(('DISARMAMENT AGREEMENTS') , na=False,regex=False)] = "Disarment"
outta["Category"][outta['keywords'].str.contains(('CEASEFIRES') , na=False,regex=False)] = "Disarment"
outta["Category"][outta['keywords'].str.contains(('ARMED INCIDENTS') , na=False,regex=False)] = "War"
outta["Category"][outta['keywords'].str.contains(('WEAPONS OF MASS DESTRUCTION') , na=False,regex=False)] = "War"
outta["Category"][outta['keywords'].str.contains(('LANDMINES') , na=False,regex=False)] = "War"
outta["Category"][outta['keywords'].str.contains(('CONSULTATIONS') , na=False,regex=False)] = "Consultations"
outta["Category"][outta['keywords'].str.contains(('NEGOTIATION') , na=False,regex=False)] = "Negotiation"
outta["Category"][outta['keywords'].str.contains(('SANCTIONS') , na=False,regex=False)] = "Sanctions"
outta["Category"][outta['keywords'].str.contains(('HUMANITARIAN ASSISTANCE') , na=False,regex=False)] = "Assistance"
outta["Category"][outta['keywords'].str.contains(('FISSIONABLE MATERIALS') , na=False,regex=False)] = "Materials"
outta["Category"][outta['keywords'].str.contains(('OUTER SPACE') , na=False,regex=False)] = "Space"

# %%
outta.groupby('Category')[['jobno']].count()
# Out:
#                jobno
# Category
# Assistance      4348
# Consultations   1803
# Disarment       2427
# Materials        268
# Negotiation     1863
# Nuclear         1278
# Others         80592
# Peace           6648
# Sanctions       3516
# Space            710
# War             4435

# %%
outta = outta[outta.Category != 'Others']

# %%
outta.to_csv("russian.csv",index=False)
