# %%
import xml.etree.ElementTree as et
import glob
import os
import string
from os import walk
path = "Downloads/SPANISH/UNv1.0-TEI/es/"
paths = [os.path.join(root, name)
        for root, dirs, files in os.walk(path)
             for name in files
             if name.endswith((".xml"))]

# %%
from lxml import etree
parser = etree.XMLParser(recover=True)


outcry = {}
body = ['' for i in range(len(paths))]
outcry['symbol'] = []
outcry['jobno']= []
outcry['dat'] = []
outcry['language'] = []
outcry['keywords'] = [[] for i in range(len(paths))]
outcry['paths'] = []
outcry['text'] = [[] for i in range(len(paths))]
for i in range(len(paths)):       

        tree = tree = et.parse(paths[i],parser=parser)
        root = tree.getroot()
        
        outcry['paths'].append(paths[i])
        
        for idno in root.findall(".//idno") or []:
            if idno.text is not None:
                outcry[idno.get('type')].append(idno.text) 
                
  
        for date in tree.findall('.//date') or []:
            if date.text is not None:
                   outcry['dat'].append(date.text) 
                    
        for lg in tree.findall('.//language')or []:
                if lg.text is not None:
                     outcry['language'].append(lg.text)
                        
        for keyword in root.find(".//keywords") or []:
               if keyword.text is not None:
                    outcry['keywords'][i].append(keyword.text)
                                
                        
        for paragraph in tree.findall(".//body/p"):
            for sentence in paragraph.findall("s"):
                if sentence.text is not None:
                    body[i] += sentence.text
                    if sentence.text[-1:] not in string.punctuation:
                        body[i] += '. '
                    elif sentence == paragraph.findall("s")[-1]:
                        #if it's the last sentence in a paragraph
                        if sentence.text[-1:] in string.punctuation:
                            #replace last element for a period
                            body[i] = body[i][:-1]
                        body[i] += '. '
                    else:
                        body[i] += ' '
                        
                    outcry['text'][i] = body[i]
# Out:
# C:\Users\AlexVaqueroRamirez\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: FutureWarning: The behavior of this method will change in future versions. Use specific 'len(elem)' or 'elem is not None' test instead.

# %%
print(len(outcry['jobno']))
# Out:
# 130017

# %%
indices = [i for i, x in enumerate(outcry['keywords']) if x == []]

# %%
print(len(indices))
# Out:
# 24660

# %%
import pandas as pd
outta = pd.DataFrame.from_dict(outcry,orient='index')
outta = outta.transpose()
outta.drop(outta.index[indices],inplace=True,)
outta = outta.reset_index(drop=True)
s = pd.Series(range(len(outta)))
outta.set_index(s,inplace=True,append = True)
outta
# Out:
#                                  symbol     jobno       dat language  \
# 0      0                  A/54/15(SUPP)  N0224370  20020206  Spanish
# 1      1        A/55/7ANDADD.1-10(SUPP)  N0261099  20020101  Spanish
# 2      2                      A/56/1000  N0247012  20020711  Spanish
# 3      3                      A/56/1001  N0247395  20020710  Spanish
# 4      4                      A/56/1002  N0247662  20020710  Spanish
# 5      5                      A/56/1003  N0247616  20020710  Spanish
# 6      6                      A/56/1004  N0247696  20020712  Spanish
# 7      7                      A/56/1005  N0248380  20020723  Spanish
# 8      8                      A/56/1006  N0248399  20020717  Spanish
# 9      9                      A/56/1007  N0248570  20020718  Spanish
# 10     10                     A/56/1008  N0248716  20020719  Spanish
# 11     11                     A/56/1009  N0248725  20020724  Spanish
# 12     12                     A/56/1010  N0249043  20020722  Spanish
# 13     13                     A/56/1011  N0248954  20020722  Spanish
# 14     14                     A/56/1012  N0249379  20020724  Spanish
# 15     15                     A/56/1013  N0249984  20020726  Spanish
# 16     16                     A/56/1014  N0249919  20020726  Spanish
# 17     17                     A/56/1015  N0250358  20020731  Spanish
# 18     18                     A/56/1016  N0250334  20020731  Spanish
# 19     19                     A/56/1017  N0250351  20020731  Spanish
# 20     20                     A/56/1018  N0250627  20020801  Spanish
# 21     21                     A/56/1019  N0250766  20020802  Spanish
# 22     22                     A/56/1020  N0250799  20020805  Spanish
# 23     23                     A/56/1021  N0251268  20020807  Spanish
# 24     24                     A/56/1022  N0251319  20020807  Spanish
# 25     25                     A/56/1023  N0252167  20020814  Spanish
# 26     26                     A/56/1024  N0252010  20020813  Spanish
# 27     27                     A/56/1025  N0252194  20020814  Spanish
# 28     28                     A/56/1026  N0252770  20020815  Spanish
# 29     29                     A/56/1027  N0252561  20020815  Spanish
# ...                                 ...       ...       ...      ...
# 105327 105327             TD/B/COM.3/45  G0153532  20011221  Spanish
# 105328 105328        TD/B/COM.3/EM.13/2  G0152705  20010905  Spanish
# 105329 105329        TD/B/COM.3/EM.14/2  G0152630  20010828  English
# 105330 105330       TD/B/C.5/ORIGIN/115  G0150862  20010314  Spanish
# 105331 105331       TD/B/C.5/ORIGIN/117  G0151038  20010327  Spanish
# 105332 105332       TD/B/C.5/ORIGIN/119  G0151693  20010601  Spanish
# 105333 105333       TD/B/C.5/ORIGIN/120  G0151698  20010601  Spanish
# 105334 105334       TD/B/C.5/ORIGIN/121  G0151703  20010601  Spanish
# 105335 105335             TD/B/EX(26)/2  G0150317  20010205  Spanish
# 105336 105336             TD/B/EX(26)/3  G0152227  20010802  Spanish
# 105337 105337             TD/B/EX(27)/2  G0151586  20010509  Spanish
# 105338 105338             TD/B/EX(27)/3  G0152356  20010817  Spanish
# 105339 105339          TD/B/LDC/AC.1/17  G0151774  20010613  Spanish
# 105340 105340               TD/B/WP/143  G0151948  20010705     None
# 105341 105341              TD/COCOA.9/7  G0150839  20010313     None
# 105342 105342              TD/COCOA.9/8  G0150819  20010313     None
# 105343 105343               TD/JUTE.4/3  G0150469  20010213     None
# 105344 105344               TD/JUTE.4/4  G0150462  20010213     None
# 105345 105345               TD/JUTE.4/6  G0150888  20010301     None
# 105346 105346             UNCTAD/EDM/19  G0152790  20010101     None
# 105347 105347        UNCTAD/LDC/MISC.61  G0151050  20010328     None
# 105348 105348        UNCTAD/LDC/MISC.64  G0150583  20010223     None
# 105349 105349  UNCTAD/LDC/MISC.64/ADD.1  G0150856  20010314     None
# 105350 105350         UNCTAD/SDTE/TLB/1  G0150095  20010112     None
# 105351 105351              UNEP/GC/21/5  K0100013  20010118     None
# 105352 105352              UNEP/GC/21/9  K0100284  20010214     None
# 105353 105353        UNEP/GC/21/4/ADD.1  K0100028  20010120     None
# 105354 105354        UNEP/GC/21/7/ADD.2  K0100042  20010125     None
# 105355 105355         UNEP/GC/21/INF/24  K0100075  20010201     None
# 105356 105356        UNEP/GC/22/2/ADD.4  K0263034  20011028     None
#
#                                                         keywords  \
# 0      0       [INTERNATIONAL TRADE, SUBSIDIARY BODIES, GLOBA...
# 1      1       [ADMINISTRATION, BUDGETARY POLICY, BUDGET PERF...
# 2      2       [INTERIM GOVERNMENTS, INTERNAL SECURITY, POST-...
# 3      3       [BORDER INCIDENTS, ARMED INCIDENTS, ISRAEL, LE...
# 4      4       [TERRORISM, COUNTER-TERRORISM, AMERICAS, TREAT...
# 5      5       [SPECIAL MISSIONS, VERIFICATION, PEACE TREATIE...
# 6      6       [BORDER INCIDENTS, LEBANON, ISRAEL, MIDDLE EAS...
# 7      7       [CONSULTATIONS, REPORT PREPARATION, GUIDELINES...
# 8      8       [ARMED INCIDENTS, BOMBINGS, ISRAEL, TERRITORIE...
# 9      9       [AIRSPACE, CYPRUS, AIRCRAFT, TURKEY, CYPRUS QU...
# 10     10      [BOMBINGS, ARMED INCIDENTS, TEL AVIV-JAFFA (IS...
# 11     11                                          [SWITZERLAND]
# 12     12      [MILITARY PERSONNEL, TURKEY, CYPRUS, CYPRUS QU...
# 13     13      [PEACEKEEPING OPERATIONS, LEBANON, BORDER INCI...
# 14     14      [BORDER INCIDENTS, ISRAEL, LEBANON, AIRSPACE, ...
# 15     15      [PEACEBUILDING, INTERNAL SECURITY, HAITI, HAIT...
# 16     16      [ARMED INCIDENTS, HEBRON (WEST BANK), GAZA STR...
# 17     17      [GLOBALIZATION, POLITICAL VIOLENCE, ECONOMIC D...
# 18     18      [ARMED INCIDENTS, ISRAEL, TERRITORIES OCCUPIED...
# 19     19      [LEGAL STATUS, SEABED, CASPIAN SEA, MARITIME B...
# 20     20      [BOMBINGS, JERUSALEM, TERRITORIES OCCUPIED BY ...
# 21     21      [ARMED INCIDENTS, GAZA STRIP (STATE OF PALESTI...
# 22     22           [DEMOCRATIC REPUBLIC OF THE CONGO SITUATION]
# 23     23      [BOMBINGS, JERUSALEM, ISRAEL, TERRITORIES OCCU...
# 24     24      [ORGANIZED CRIME, TRANSNATIONAL CRIME, DECLARA...
# 25     25      [ELECTIONS, JAMMU AND KASHMIR, INDIA, DISPUTE ...
# 26     26      [REGIONAL COOPERATION, AFRICA, COOPERATION BET...
# 27     27      [ARMED INCIDENTS, ISRAEL, TERRITORIES OCCUPIED...
# 28     28      [REGIONAL SECURITY, REGIONAL COOPERATION, ARAB...
# 29     29      [BORDER INCIDENTS, LEBANON, ISRAEL, MIDDLE EAS...
# ...                                                          ...
# 105327 105327  [ENTERPRISE DEVELOPMENT, ELECTRONIC COMMERCE, ...
# 105328 105328  [SMALL ENTERPRISES, ENTERPRISE DEVELOPMENT, BU...
# 105329 105329  [GENDER MAINSTREAMING, ECONOMIC DEVELOPMENT, W...
# 105330 105330  [CERTIFICATES OF ORIGIN, CERTIFYING OFFICERS, ...
# 105331 105331  [CERTIFICATES OF ORIGIN, CERTIFYING OFFICERS, ...
# 105332 105332  [CERTIFICATES OF ORIGIN, CERTIFYING OFFICERS, ...
# 105333 105333  [CERTIFICATES OF ORIGIN, CERTIFYING OFFICERS, ...
# 105334 105334  [CERTIFICATES OF ORIGIN, CERTIFYING OFFICERS, ...
# 105335 105335  [TRADE POLICY, ISLAMIC COUNTRIES, INTERNATIONA...
# 105336 105336  [INTERNATIONAL TRADE, ECONOMIC DEVELOPMENT, DE...
# 105337 105337  [ECONOMIC DEVELOPMENT, TECHNICAL COOPERATION, ...
# 105338 105338  [ECONOMIC DEVELOPMENT, AFRICA, TECHNICAL COOPE...
# 105339 105339  [LANDLOCKED DEVELOPING COUNTRIES, TRANSIT, TRA...
# 105340 105340  [TRADE FACILITATION CENTRES, TRADE INFORMATION...
# 105341 105341  [COCOA, COMMODITY AGREEMENTS, INTERNATIONAL CO...
# 105342 105342  [COCOA, COMMODITY AGREEMENTS, SIGNATURES, ACCE...
# 105343 105343  [JUTE, COMMODITY TRADE, PRODUCER-CONSUMER GROUPS]
# 105344 105344  [JUTE, PRODUCER-CONSUMER GROUPS, VOTING, BUDGE...
# 105345 105345  [JUTE, COMMODITY TRADE, PRODUCER-CONSUMER GROU...
# 105346 105346  [ECONOMIC DEVELOPMENT, INTERNATIONAL TRADE, LE...
# 105347 105347  [TRANSIT, TRANSPORT FACILITATION, NORTHEAST AS...
# 105348 105348  [LEAST DEVELOPED COUNTRIES, TOURISM, ECONOMIC ...
# 105349 105349  [LEAST DEVELOPED COUNTRIES, TOURISM, TOURISM D...
# 105350 105350  [INFORMATION TECHNOLOGY, PORT MANAGEMENT, MANA...
# 105351 105351  [ENVIRONMENTAL MANAGEMENT, ENVIRONMENTAL INFOR...
# 105352 105352  [ENVIRONMENTAL AGREEMENTS, ENVIRONMENTAL POLIC...
# 105353 105353  [MARINE ENVIRONMENT, OCEANS, PROGRAMMES OF ACT...
# 105354 105354  [ENVIRONMENTAL MONITORING, COMMUNICATION SATEL...
# 105355 105355                             [RESOURCES ALLOCATION]
# 105356 105356  [ENVIRONMENTAL PROTECTION, AFRICA, PROGRAMME I...
#
#                                                            paths  \
# 0      0       Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\54\...
# 1      1       Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\55\...
# 2      2       Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 3      3       Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 4      4       Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 5      5       Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 6      6       Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 7      7       Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 8      8       Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 9      9       Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 10     10      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 11     11      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 12     12      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 13     13      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 14     14      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 15     15      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 16     16      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 17     17      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 18     18      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 19     19      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 20     20      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 21     21      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 22     22      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 23     23      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 24     24      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 25     25      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 26     26      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 27     27      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 28     28      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# 29     29      Downloads/SPANISH/UNv1.0-TEI/es/200\2002\a\56\...
# ...                                                          ...
# 105327 105327  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\b\...
# 105328 105328  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\b\...
# 105329 105329  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\b\...
# 105330 105330  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\b\...
# 105331 105331  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\b\...
# 105332 105332  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\b\...
# 105333 105333  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\b\...
# 105334 105334  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\b\...
# 105335 105335  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\b\...
# 105336 105336  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\b\...
# 105337 105337  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\b\...
# 105338 105338  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\b\...
# 105339 105339  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\b\...
# 105340 105340  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\b\...
# 105341 105341  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\co...
# 105342 105342  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\co...
# 105343 105343  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\ju...
# 105344 105344  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\ju...
# 105345 105345  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\td\ju...
# 105346 105346  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\uncta...
# 105347 105347  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\uncta...
# 105348 105348  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\uncta...
# 105349 105349  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\uncta...
# 105350 105350  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\uncta...
# 105351 105351  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\unep\...
# 105352 105352  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\unep\...
# 105353 105353  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\unep\...
# 105354 105354  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\unep\...
# 105355 105355  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\unep\...
# 105356 105356  Downloads/SPANISH/UNv1.0-TEI/es/902\2001\unep\...
#
#                                                             text
# 0      0       Naciones Unidas. Conferencia de las. Naciones ...
# 1      1       Naciones Unidas. Comisión Consultiva en Asunto...
# 2      2       Asamblea General. Consejo de Seguridad. Quincu...
# 3      3       Asamblea General. Consejo de Seguridad. Quincu...
# 4      4       Asamblea General. Quincuagésimo sexto período ...
# 5      5       Quincuagésimo sexto período de sesiones. Tema ...
# 6      6       Asamblea General. Consejo de Seguridad. Quincu...
# 7      7       Quincuagésimo sexto período de sesiones. Tema ...
# 8      8       Asamblea General. Consejo de Seguridad. Quincu...
# 9      9       Asamblea General. Quincuagésimo sexto período ...
# 10     10      Asamblea General. Consejo de Seguridad. Quincu...
# 11     11      Asamblea General. Quincuagésimo sexto período ...
# 12     12      Asamblea General. Consejo de Seguridad. Quincu...
# 13     13      Asamblea General. Consejo de Seguridad. Quincu...
# 14     14      Asamblea General. Quincuagésimo sexto período ...
# 15     15      Quincuagésimo sexto período de sesiones. Tema ...
# 16     16      Asamblea General. Consejo de Seguridad. Quincu...
# 17     17      Quincuagésimo sexto período de sesiones. Tema ...
# 18     18      Asamblea General. Quincuagésimo sexto período ...
# 19     19      Quincuagésimo sexto período de sesiones. Temas...
# 20     20      Asamblea General. Quincuagésimo sexto período ...
# 21     21      Asamblea General. Consejo de Seguridad. Quincu...
# 22     22      Quincuagésimo sexto período de sesiones. Tema ...
# 23     23      Asamblea General. Quincuagésimo sexto período ...
# 24     24      Quincuagésimo sexto período de sesiones. Tema ...
# 25     25      Asamblea General. Consejo de Seguridad. Quincu...
# 26     26      Quincuagésimo sexto período de sesiones. * A f...
# 27     27      Asamblea General. Quincuagésimo sexto período ...
# 28     28      Asamblea General. Consejo de Seguridad. Quincu...
# 29     29      Asamblea General. Consejo de Seguridad. Quincu...
# ...                                                          ...
# 105327 105327  Distr. GENERAL. TD/B/COM.3/45. 21 de diciembre...
# 105328 105328  Distr. GENERAL. TD/B/COM.3/EM.13/2. 5 de septi...
# 105329 105329  Distr. GENERAL. TD/B/COM.3/EM.14/2. 28 de agos...
# 105330 105330  NACIONES. UNIDAS. Distr. GENERAL. TD/B/C.5/ORI...
# 105331 105331  Distr. GENERAL. TD/B/C.5/ORIGIN/117. 27 de mar...
# 105332 105332  Distr. GENERAL. TD/B/C.5/ORIGIN/119. 1º de jun...
# 105333 105333  NACIONES. UNIDAS. Distr. GENERAL. TD/B/C.5/ORI...
# 105334 105334  NACIONES. UNIDAS. Distr. GENERAL. TD/B/C.5/ORI...
# 105335 105335  Distr. GENERAL. TD/B/EX(26)/2. 5 de febrero de...
# 105336 105336  TD/B/EX(26)/3. CONFERENCIA DE LAS NACIONES UNI...
# 105337 105337  Distr. GENERAL. TD/B/EX(27)/2. 9 de mayo de 20...
# 105338 105338  TD/B/EX(27)/3. CONFERENCIA DE LAS NACIONES UNI...
# 105339 105339  Distr. GENERAL. TD/B/LDC/AC.1/17. 13 de junio ...
# 105340 105340  Distr. GENERAL. TD/B/WP/143. 5 de julio de 200...
# 105341 105341  Distr. GENERAL. TD/COCOA.9/7. 13 de marzo de 2...
# 105342 105342  Distr. GENERAL. TD/COCOA.9/8. 13 de marzo de 2...
# 105343 105343  Distr. GENERAL. TD/JUTE.4/3. 13 de febrero de ...
# 105344 105344  Distr. GENERAL. TD/JUTE.4/4. 13 de febrero de ...
# 105345 105345  TD/JUTE.4/6. CONFERENCIA DE LAS NACIONES UNIDA...
# 105346 105346  CONFERENCIA DE LAS NACIONES UNIDAS SOBRE COMER...
# 105347 105347  Distr. GENERAL. UNCTAD/LDC/Misc.61. 28 de marz...
# 105348 105348  Distr. GENERAL. UNCTAD/LDC/Misc.64. 23 de febr...
# 105349 105349  Distr. GENERAL. UNCTAD/LDC/Misc.64/Add.1. 14 d...
# 105350 105350  Distr. GENERAL. UNCTAD/SDTE/TLB/1. 12 de enero...
# 105351 105351  NACIONES. UNIDAS. Consejo de Administración de...
# 105352 105352  NACIONES. UNIDAS. Consejo de Administración de...
# 105353 105353  NACIONES. UNIDAS. Consejo de Administración de...
# 105354 105354  NACIONES. UNIDAS. Consejo de Administración de...
# 105355 105355  NACIONES. UNIDAS. Consejo de Administración de...
# 105356 105356  NACIONES. UNIDAS. EP. Consejo de Administració...
#
# [105357 rows x 7 columns]

# %%
outta['language'].fillna("Spanish",inplace=True)

# %%
outta.insert(5, "Category",str, True)

# %%
outta.columns
# Out:
# Index(['symbol', 'jobno', 'dat', 'language', 'keywords', 'Category', 'paths',
#        'text'],
#       dtype='object')

# %%
outta.to_csv("spanish_complete.csv",index=False)

# %%
outta['Category'] = "Others"
outta["Category"][outta['keywords'].str.contains(('PEACEKEEPING OPERATIONS') , na=False,regex=False)] = "Peace"
outta["Category"][outta['keywords'].str.contains(('TROOP WITHDRAWAL') , na=False,regex=False)] = "Peace"
outta["Category"][outta['keywords'].str.contains(('NUCLEAR DISARMAMENT, ') , na=False,regex=False)] = "Nuclear"
outta["Category"][outta['keywords'].str.contains(('NUCLEAR NON-PROLIFERATION') , na=False,regex=False)] = "Nuclear"
outta["Category"][outta['keywords'].str.contains(('NUCLEAR WEAPON TESTS') , na=False,regex=False)] = "Nuclear"
outta["Category"][outta['keywords'].str.contains(('NUCLEAR WEAPONS') , na=False,regex=False)] = "Nuclear"
outta["Category"][outta['keywords'].str.contains(('DISARMAMENT NEGOTIATIONS') , na=False,regex=False)] = "Disarment"
outta["Category"][outta['keywords'].str.contains(('DISARMAMENT') , na=False,regex=False)] = "Disarment"
outta["Category"][outta['keywords'].str.contains(('DISARMAMENT AGREEMENTS') , na=False,regex=False)] = "Disarment"
outta["Category"][outta['keywords'].str.contains(('CEASEFIRES') , na=False,regex=False)] = "Disarment"
outta["Category"][outta['keywords'].str.contains(('ARMED INCIDENTS') , na=False,regex=False)] = "War"
outta["Category"][outta['keywords'].str.contains(('WEAPONS OF MASS DESTRUCTION') , na=False,regex=False)] = "War"
outta["Category"][outta['keywords'].str.contains(('LANDMINES') , na=False,regex=False)] = "War"
outta["Category"][outta['keywords'].str.contains(('CONSULTATIONS') , na=False,regex=False)] = "Consultations"
outta["Category"][outta['keywords'].str.contains(('NEGOTIATION') , na=False,regex=False)] = "Negotiation"
outta["Category"][outta['keywords'].str.contains(('SANCTIONS') , na=False,regex=False)] = "Sanctions"
outta["Category"][outta['keywords'].str.contains(('HUMANITARIAN ASSISTANCE') , na=False,regex=False)] = "Assistance"
outta["Category"][outta['keywords'].str.contains(('FISSIONABLE MATERIALS') , na=False,regex=False)] = "Materials"
outta["Category"][outta['keywords'].str.contains(('OUTER SPACE') , na=False,regex=False)] = "Space"
#outta.info()

# %%
outta.groupby('Category')[['jobno']].count()
# Out:
#                jobno
# Category
# Assistance      4632
# Consultations   1779
# Disarment       2562
# Materials        278
# Negotiation     1978
# Nuclear         1306
# Others         76568
# Peace           7115
# Sanctions       3764
# Space            722
# War             4653

# %%
outta = outta[outta.Category != 'Others']

# %%
outta.to_csv("spanish.csv",index=False)

# %%
xmlfiles.sort()
print(len(xmlfiles))
# Out:
# 130275

# %%
print(xmlfiles[10])
# Out:
# D:/un dataset/SPANISH/UNv1.0-TEI/es\1992\a\c_5\47\sr_10.xml

# %%
pathf = "D:/un dataset/FRENCH/UNv1.0-TEI/fr" 
xmlfilesf = [os.path.join(root, name)
             for root, dirs, files in os.walk(pathf)
             for name in files
             if name.endswith((".xml"))]

# %%
xmlfilesf.sort()
print(len(xmlfilesf))
# Out:
# 158800

# %%
pathr = "D:/un dataset/RUSSIAN/UNv1.0-TEI/ru" 
xmlfilesr = [os.path.join(root, name)
             for root, dirs, files in os.walk(pathr)
             for name in files
             if name.endswith((".xml"))]

# %%
xmlfilesr.sort()
print(len(xmlfilesr))
# Out:
# 138168

# %%
pathe = "Downloads/ENGLISH/UNv1.0-TEI/en"
xmlfilese = [os.path.join(root, name)
             for root, dirs, files in os.walk(pathe)
             for name in files
             if name.endswith((".xml"))]

# %%
xmlfilese.sort()
print(len(xmlfilese))
# Out:
# 159054

# %%
import xml.etree.ElementTree as et
import glob
import os
import string


pat = "D:/un dataset/SPANISH/UNv1.0-TEI/es/**/**/**/"
arxius = glob.glob(pat + '*.xml')
arxius.sort()
print(arxius)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
outspa = {}


outspa['keywords'] = list()

for infil in glob.glob( os.path.join(pat, '*.xml') ):
        

        tree = et.parse(infil)
        root = tree.getroot()
        
        

        for keyword in root.find(".//keywords") or [] :
            if keyword.text is not None:
                outspa['keywords'].append(keyword.text)

# %%
outspa
# Out:
# {'keywords': ['ELECTION OF OFFICERS',
#   'REFUGEE ASSISTANCE',
#   'REFUGEE PROTECTION',
#   'EMERGENCY RELIEF',
#   'REPATRIATION',
#   'INTER-AGENCY COOPERATION',
#   'COOPERATION BETWEEN ORGANIZATIONS',
#   'AID COORDINATION',
#   'PROGRAMME IMPLEMENTATION',
#   'INTERNATIONAL CRIMES',
#   'INTERNATIONAL CRIMINAL COURTS',
#   'INTERNATIONAL CRIMINAL JURISDICTION',
#   'PERIODIC REPORTS',
#   'PRISONER TREATMENT',
#   'DETAINED PERSONS',
#   'LAWS AND REGULATIONS',
#   'GERMANY',
#   'TORTURE AND OTHER CRUEL TREATMENT',
#   'TREATIES',
#   'PRISONER TREATMENT',
#   'PERIODIC REPORTS',
#   'LIBYA',
#   'MEXICO',
#   'TORTURE AND OTHER CRUEL TREATMENT',
#   'TREATIES',
#   'WORK ORGANIZATION',
#   'CONFERENCES',
#   'HUMAN RIGHTS',
#   'TORTURE AND OTHER CRUEL TREATMENT',
#   'TREATIES',
#   'CIVIL AND POLITICAL RIGHTS',
#   'PERIODIC REPORTS',
#   'TREATIES',
#   'CIVIL AND POLITICAL RIGHTS',
#   'PERIODIC REPORTS',
#   'TREATIES',
#   'CIVIL AND POLITICAL RIGHTS',
#   'PERIODIC REPORTS',
#   'TREATIES',
#   'CIVIL AND POLITICAL RIGHTS',
#   'PERIODIC REPORTS',
#   'TREATIES',
#   'PERIODIC REPORTS',
#   'CONSTITUTIONS',
#   'ISLAMIC LAW',
#   'CIVIL AND POLITICAL RIGHTS',
#   "WOMEN'S RIGHTS",
#   'RELIGIOUS FREEDOM',
#   'IRAN (ISLAMIC REPUBLIC OF)',
#   'SERBS',
#   'DETAINED PERSONS',
#   'CIVIL AND POLITICAL RIGHTS',
#   'PERIODIC REPORTS',
#   'POLITICAL CONDITIONS',
#   'MINORITIES',
#   'ETHNIC AND RACIAL GROUPS',
#   'CONSTITUTIONS',
#   'CROATIA',
#   'TREATIES',
#   'SELF-DETERMINATION OF PEOPLES',
#   'HUMAN RIGHTS VIOLATIONS',
#   'TORTURE AND OTHER CRUEL TREATMENT',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'ELECTION OF MEMBERS',
#   'CIVIL AND POLITICAL RIGHTS',
#   'ELECTION OF OFFICERS',
#   'RACIAL DISCRIMINATION',
#   'PERIODIC REPORTS',
#   'TREATIES',
#   'RIGHTS OF THE CHILD',
#   'TREATIES',
#   'PERIODIC REPORTS',
#   'SEXUAL HARASSMENT',
#   'GRIEVANCE PROCEDURES',
#   'LABOUR DISCIPLINE',
#   'SEXUAL HARASSMENT',
#   "WOMEN'S ADVANCEMENT",
#   "REPRESENTATIVES' CREDENTIALS",
#   'HUMANITARIAN ASSISTANCE',
#   'LEBANON',
#   'CYPRUS QUESTION',
#   'MIDDLE EAST',
#   'MIDDLE EAST SITUATION',
#   'PALESTINE QUESTION',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'ELECTIONS',
#   'PACIFIC ISLANDS (TRUST TERRITORY) QUESTION',
#   'WESTERN SAHARA QUESTION',
#   'HAITI',
#   'WRITTEN COMMUNICATIONS',
#   'ANGOLA',
#   'ANGOLA SITUATION',
#   'CAMBODIA SITUATION',
#   'CENTRAL AMERICA SITUATION',
#   'ELECTION OF MEMBERS',
#   'INTERNATIONAL SECURITY',
#   'IRAN (ISLAMIC REPUBLIC OF)',
#   'IRAQ',
#   'IRAQ-KUWAIT SITUATION',
#   'IRAQI REFUGEES',
#   'KURDS',
#   'LEBANON SITUATION',
#   'LIBERIA SITUATION',
#   'LIECHTENSTEIN',
#   'MEMBERS',
#   'SANCTIONS',
#   'TRUCE SUPERVISION',
#   'NEGOTIATION',
#   'POLITICAL CONDITIONS',
#   'HAITI',
#   'HAITI QUESTION',
#   'MAPS',
#   'PEACEKEEPING OPERATIONS',
#   'CYPRUS',
#   'FINANCING',
#   'REIMBURSEMENT',
#   'BUDGET CONTRIBUTIONS',
#   'FINANCING',
#   'INTERNATIONAL CRIMINAL COURTS',
#   'FORMER YUGOSLAVIA SITUATION',
#   'INTERNATIONAL CRIMINAL COURTS',
#   'JUDGES',
#   'WAR CRIMES',
#   'FORMER YUGOSLAVIA SITUATION',
#   'PEACEKEEPING OPERATIONS',
#   'CYPRUS',
#   'FINANCING',
#   'ELECTION OF MEMBERS',
#   'JUDGES',
#   'ELECTION OF MEMBERS',
#   'JUDGES',
#   'BIOGRAPHY',
#   'POPULATION COMPOSITION',
#   'CYPRUS',
#   'CYPRUS QUESTION',
#   'TURKISH CYPRIOT COMMUNITY',
#   'CEASEFIRES',
#   'ISRAEL',
#   'PALESTINE QUESTION',
#   'MIDDLE EAST SITUATION',
#   'DISPUTE SETTLEMENT',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'PALESTINIANS',
#   'DECLARATIONS',
#   'POLITICAL CONDITIONS',
#   'NICARAGUA',
#   'NICARAGUA SITUATION',
#   'DECLARATIONS',
#   'SANCTIONS',
#   'POLITICAL CONDITIONS',
#   'HAITI',
#   'HAITI QUESTION',
#   'INTERNATIONAL YEARS',
#   'FAMILY',
#   'HUMAN RIGHTS',
#   'RIGHT TO LIFE',
#   'DETAINED PERSONS',
#   'PRISONER TREATMENT',
#   'FREEDOM OF ASSOCIATION',
#   'TRADE UNION RIGHTS',
#   'ADMINISTRATION OF JUSTICE',
#   'FREEDOM OF EXPRESSION',
#   'CIVIL AND POLITICAL RIGHTS',
#   'LAW REFORM',
#   'AMPARO',
#   'ARMED FORCES',
#   'MILITARY EDUCATION',
#   'HUMAN RIGHTS EDUCATION',
#   'LAW ENFORCEMENT OFFICIALS',
#   'EL SALVADOR',
#   'HUMAN RIGHTS VIOLATIONS',
#   'EXTRALEGAL EXECUTIONS',
#   'TORTURE AND OTHER CRUEL TREATMENT',
#   'DUE PROCESS OF LAW',
#   'RECOMMENDATIONS',
#   'IDENTIFICATION CARDS',
#   'FINANCING',
#   'IRAQ',
#   'KUWAIT',
#   'FINANCING',
#   'INTERNATIONAL CRIMINAL COURTS',
#   'PEACEKEEPING OPERATIONS',
#   'CYPRUS',
#   'BUDGET CONTRIBUTIONS',
#   'FINANCING',
#   'DIPLOMATIC RELATIONS',
#   'HAITI',
#   'MEXICO',
#   'PEACE TREATIES',
#   'ISRAEL',
#   'PALESTINIANS',
#   'PALESTINE QUESTION',
#   'DISPUTE SETTLEMENT',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'DECLARATIONS',
#   'PEACE TREATIES',
#   'ISRAEL',
#   'PALESTINE QUESTION',
#   'MIDDLE EAST SITUATION',
#   'DISPUTE SETTLEMENT',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'PALESTINIANS',
#   'DECLARATIONS',
#   'CEASEFIRES',
#   'ISRAEL',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'PALESTINIANS',
#   'FINANCIAL ASSISTANCE',
#   'NEGOTIATION',
#   'ECONOMIC COOPERATION',
#   'MIDDLE EAST SITUATION',
#   'DISPUTE SETTLEMENT',
#   'PALESTINE QUESTION',
#   'CEASEFIRES',
#   'ISRAEL',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'PALESTINIANS',
#   'SELF-DETERMINATION OF PEOPLES',
#   'PALESTINE QUESTION',
#   'DISPUTE SETTLEMENT',
#   'SELF-RULE',
#   'DECLARATIONS',
#   'CEASEFIRES',
#   'ISRAEL',
#   'PALESTINE QUESTION',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'DISPUTE SETTLEMENT',
#   'PALESTINIANS',
#   'DECLARATIONS',
#   'SELF-RULE',
#   'STATE SUCCESSION',
#   'STATE REPRESENTATION',
#   'YUGOSLAVIA',
#   'MEMBERS',
#   'PARTICIPANTS',
#   'EMERGENCY RELIEF',
#   'NEGOTIATION',
#   'HUMAN RIGHTS',
#   'HAITI',
#   'POLITICAL STATUS',
#   'WEST BANK (STATE OF PALESTINE)',
#   'GAZA STRIP (STATE OF PALESTINE)',
#   'CEASEFIRES',
#   'ISRAEL',
#   'PALESTINIANS',
#   'DISPUTE SETTLEMENT',
#   'PALESTINE QUESTION',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'DECLARATIONS',
#   'SELF-RULE',
#   'ECONOMIC POLICY',
#   'TRADE POLICY',
#   'AFRICA',
#   'WORK ORGANIZATION',
#   'COORDINATION WITHIN UN SYSTEM',
#   'PROGRAMME IMPLEMENTATION',
#   "WOMEN'S ADVANCEMENT",
#   'PROGRAMME MANAGEMENT',
#   'MEDIUM-TERM PLAN',
#   'ECONOMIC DEVELOPMENT',
#   'DISPUTES',
#   'LIBYA',
#   'UNITED STATES',
#   'BELIZE',
#   'GUATEMALA',
#   'POLITICAL CONDITIONS',
#   'SOUTH AFRICA',
#   'SANCTIONS',
#   'CEASEFIRES',
#   'ARMS EMBARGO',
#   'PEACEKEEPING OPERATIONS',
#   'BOUNDARIES',
#   'YUGOSLAVIA',
#   'BOSNIA AND HERZEGOVINA',
#   'CROATIA',
#   'HUMANITARIAN ASSISTANCE',
#   'AIRCRAFT',
#   'FRANCE',
#   'CUBA',
#   'ARMED INCIDENTS',
#   'VENEZUELA (BOLIVARIAN REPUBLIC OF)',
#   'NUCLEAR-WEAPON-FREE ZONES',
#   'KOREAN PENINSULA',
#   'TROOP WITHDRAWAL',
#   'ESTONIA',
#   'LATVIA',
#   'LITHUANIA',
#   'RUSSIAN FEDERATION',
#   'IRAQ',
#   'KUWAIT',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'IRAQ-KUWAIT SITUATION',
#   'MIDDLE EAST SITUATION',
#   'CENTRAL AMERICA SITUATION',
#   'EL SALVADOR SITUATION',
#   'CYPRUS QUESTION',
#   'CAMBODIA SITUATION',
#   'WESTERN SAHARA QUESTION',
#   'PALESTINE QUESTION',
#   'SOMALIA SITUATION',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'AFGHANISTAN SITUATION',
#   'LIBERIA SITUATION',
#   'NAGORNY KARABAKH SITUATION',
#   'FORMER YUGOSLAVIA SITUATION',
#   'KOREAN QUESTION',
#   'PACIFIC ISLANDS (TRUST TERRITORY) QUESTION',
#   'FALKLAND ISLANDS (MALVINAS) QUESTION',
#   'EAST TIMOR QUESTION',
#   'MOZAMBIQUE SITUATION',
#   'DISPUTE SETTLEMENT',
#   'ATTACKS ON AIRCRAFT',
#   'TERRORISM',
#   'INTERNATIONAL SECURITY',
#   'DISARMAMENT',
#   'ARMS LIMITATION',
#   'PEACEMAKING',
#   'MEMBERS',
#   'ELECTION OF MEMBERS',
#   'APPOINTMENT OF OFFICIALS',
#   'CONFERENCE AND MEETING SERVICES',
#   'CALENDAR OF MEETINGS',
#   'STATISTICS',
#   'COORDINATION WITHIN UN SYSTEM',
#   'DOCUMENTS LIMITATION',
#   'MEDIUM-TERM PLAN',
#   'SUBSIDIARY BODIES',
#   'MEETING RECORDS',
#   'WORK ORGANIZATION',
#   'RULES AND REGULATIONS',
#   'DOCUMENTS',
#   'PUBLICATIONS',
#   'CIVIL AND POLITICAL RIGHTS',
#   'ALGERIA',
#   'AUSTRIA',
#   'BELARUS',
#   'BELGIUM',
#   'COLOMBIA',
#   'ECUADOR',
#   'IRAQ',
#   'MONGOLIA',
#   'MOROCCO',
#   'PERU',
#   'POLAND',
#   'REPUBLIC OF KOREA',
#   'YUGOSLAVIA',
#   'CIVIL AND POLITICAL RIGHTS',
#   'TREATIES',
#   'PERIODIC REPORTS',
#   'WRITTEN COMMUNICATIONS',
#   'SIGNATURES, ACCESSIONS, RATIFICATIONS',
#   'MEMBERS',
#   'SPECIAL MISSIONS',
#   'HAITI',
#   'CONFERENCE FACILITIES',
#   'ADDIS ABABA (ETHIOPIA)',
#   'BANGKOK (THAILAND)',
#   'BUDGET',
#   'FINANCIAL IMPLICATIONS',
#   'FIELD OFFICES',
#   'STAFFING',
#   'SALARIES AND ALLOWANCES',
#   'TOP ECHELON STAFF',
#   'SUBSIDIARY BODIES',
#   'BUDGETING',
#   'EXTRABUDGETARY FINANCING',
#   'AIR TRAVEL',
#   'REGIONAL COMMISSIONS',
#   'CRIME PREVENTION',
#   'CRIMINAL JUSTICE',
#   'OPTICAL DISKS',
#   'VACANCY MANAGEMENT',
#   'INFORMATION CENTRES',
#   'POLITICAL CONDITIONS',
#   'ELECTIONS',
#   'HAITI',
#   'DEMOCRACY',
#   'HAITI QUESTION',
#   'CONSTITUTIONS',
#   'THE FORMER YUGOSLAV REPUBLIC OF MACEDONIA',
#   'REGIONAL SECURITY',
#   'BALKAN REGION',
#   'MEMBERS',
#   'NEGOTIATION',
#   'PEACEKEEPING OPERATIONS',
#   'CYPRUS',
#   'TROOP WITHDRAWAL',
#   'TURKEY',
#   'CYPRUS QUESTION',
#   'CONFIDENCE-BUILDING MEASURES',
#   'PROGRAMME IMPLEMENTATION',
#   'TURKISH CYPRIOT COMMUNITY',
#   'GREEK CYPRIOT COMMUNITY',
#   'MEMBERS',
#   'ARMED INCIDENTS',
#   'PEACEKEEPING OPERATIONS',
#   'HUMANITARIAN ASSISTANCE',
#   'ETHNIC AND RACIAL GROUPS',
#   'BOSNIA AND HERZEGOVINA',
#   'AIRCRAFT',
#   'TURKEY',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'ETHNIC CLEANSING',
#   'CYPRUS QUESTION',
#   'TURKISH CYPRIOT COMMUNITY',
#   'DEPORTATION',
#   'ISRAEL',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'PALESTINIANS',
#   'REPATRIATION',
#   'HUMANITARIAN ASSISTANCE',
#   'BOSNIA AND HERZEGOVINA',
#   'EQUIPMENT AND SUPPLIES',
#   'MILITARY PERSONNEL',
#   'ARMED INCIDENTS',
#   'ISRAEL',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'PALESTINIANS',
#   'MILITARY ACTIVITY',
#   'UNITED STATES',
#   'POLITICAL CONDITIONS',
#   'YUGOSLAVIA',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'DISPUTE SETTLEMENT',
#   'ARMED INCIDENTS',
#   'DEPORTATION',
#   'ISRAEL',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'PALESTINIANS',
#   'ARMED INCIDENTS',
#   'ISRAEL',
#   'LEBANON',
#   'CIVILIAN PERSONS',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'YOUTH',
#   'ARMED INCIDENTS',
#   'REFUGEE CAMPS',
#   'WEST BANK (STATE OF PALESTINE)',
#   'GAZA STRIP (STATE OF PALESTINE)',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'PALESTINE QUESTION',
#   'PALESTINIANS',
#   'ARMED INCIDENTS',
#   'GAZA STRIP (STATE OF PALESTINE)',
#   'DEPORTATION',
#   'ISRAEL',
#   'PALESTINIANS',
#   'CHILDREN',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'NEGOTIATION',
#   'CONSTITUTIONS',
#   'SERBS',
#   'CROATS',
#   'MUSLIMS',
#   'BOSNIA AND HERZEGOVINA',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'HUMAN RIGHTS',
#   'CEASEFIRES',
#   'MILITARY DEMOBILIZATION',
#   'GUATEMALA',
#   'DISPUTE SETTLEMENT',
#   'VERIFICATION',
#   'TREATIES',
#   'CENTRAL AMERICA SITUATION',
#   'SIGNATURES, ACCESSIONS, RATIFICATIONS',
#   'PEACEKEEPING OPERATIONS',
#   'MOZAMBIQUE',
#   'MILITARY PERSONNEL',
#   'FINANCING',
#   'AIRCRAFT',
#   'SPECIAL ACCOUNTS',
#   'ECONOMIC INTEGRATION',
#   'ECONOMIC DEVELOPMENT',
#   'AGRICULTURAL DEVELOPMENT',
#   'FOREIGN TRADE',
#   'REGIONAL COOPERATION',
#   'REGIONAL SECURITY',
#   'LANDMINES',
#   'SOCIAL SECURITY',
#   'SOCIAL DEVELOPMENT',
#   'ENVIRONMENTAL PROTECTION',
#   'CENTRAL AMERICA',
#   'EL SALVADOR SITUATION',
#   'DRUG TRAFFIC',
#   'ILLICIT TRAFFIC',
#   'ARMS TRANSFERS',
#   'DECLARATIONS',
#   'TRADE AGREEMENTS',
#   'DEMOCRACY',
#   'FINANCING',
#   'EL SALVADOR',
#   'CONSTITUTIONS',
#   'MILITARY DEMOBILIZATION',
#   'BOSNIA AND HERZEGOVINA',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'DISPUTE SETTLEMENT',
#   'PRINCIPLES',
#   'DISARMAMENT',
#   'ARMS LIMITATION',
#   'ECONOMIC CONVERSION',
#   'NUCLEAR NON-PROLIFERATION',
#   'NUCLEAR DISARMAMENT',
#   'INTERNATIONAL SECURITY',
#   'ARMED INCIDENTS',
#   'SERBS',
#   'MUSLIMS',
#   'CEASEFIRES',
#   'HUMANITARIAN ASSISTANCE',
#   'BOSNIA AND HERZEGOVINA',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'ETHNIC CLEANSING',
#   'HUMAN RIGHTS IN ARMED CONFLICTS',
#   'NEGOTIATION',
#   'ARMED INCIDENTS',
#   'SERBS',
#   'MUSLIMS',
#   'CEASEFIRES',
#   'HUMANITARIAN ASSISTANCE',
#   'ARMS EMBARGO',
#   'BOSNIA AND HERZEGOVINA',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'ETHNIC CLEANSING',
#   'HUMAN RIGHTS IN ARMED CONFLICTS',
#   'INTERNATIONAL CRIMINAL JURISDICTION',
#   'APPOINTMENT OF OFFICIALS',
#   'SLOVAKIA',
#   'CZECH REPUBLIC',
#   'PEACEKEEPING OPERATIONS',
#   'MOZAMBIQUE',
#   'RECOMMENDATIONS',
#   'BUDGET CONTRIBUTIONS',
#   'REPORT PREPARATION',
#   'FINANCING',
#   'SPECIAL ACCOUNTS',
#   'COST EFFECTIVENESS',
#   'APPOINTMENT OF MEMBERS',
#   'CONSULTATIONS',
#   'HUMAN RIGHTS',
#   'CONSTITUTIONS',
#   'SPECIAL MISSIONS',
#   'MAPS',
#   'HAITI',
#   'DEMOCRACY',
#   'ARMED INCIDENTS',
#   'ISRAEL',
#   'PALESTINIANS',
#   'PALESTINE QUESTION',
#   'CHILDREN',
#   'REGIONAL SECURITY',
#   'REGIONAL COOPERATION',
#   'ASIA AND THE PACIFIC',
#   'CONFIDENCE-BUILDING MEASURES',
#   'ARMED INCIDENTS',
#   'DEPORTATION',
#   'ISRAEL',
#   'PALESTINIANS',
#   'PALESTINE QUESTION',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'DISAPPEARANCE OF PERSONS',
#   'MILITARY EDUCATION',
#   'RIGHT TO LIFE',
#   'HUMAN RIGHTS',
#   'FREEDOM OF MOVEMENT',
#   'FREEDOM OF ASSOCIATION',
#   'RIGHT TO A FAIR TRIAL',
#   'FREEDOM OF EXPRESSION',
#   'CIVIL AND POLITICAL RIGHTS',
#   'JUDICIAL SYSTEM',
#   'ADMINISTRATION OF JUSTICE',
#   'ARMED FORCES',
#   'HUMAN RIGHTS EDUCATION',
#   'POLICE',
#   'TRADE UNION RIGHTS',
#   'EL SALVADOR',
#   'TORTURE AND OTHER CRUEL TREATMENT',
#   'INTERNATIONAL HUMANITARIAN LAW',
#   'VERIFICATION',
#   'CEASEFIRES',
#   'BOSNIA AND HERZEGOVINA',
#   'NEGOTIATION',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'FINANCIAL IMPLICATIONS',
#   'LOCATION OF OFFICES',
#   'DEBT',
#   'FINANCING',
#   'OFFICE BUILDINGS',
#   'TRAINING AND RESEARCH INSTITUTIONS',
#   'BUDGET',
#   'BUDGET',
#   'APPROPRIATIONS',
#   'PEACEKEEPING OPERATIONS',
#   'SOMALIA',
#   'BUDGET CONTRIBUTIONS',
#   'FINANCING',
#   'COSTS',
#   'DISASTER RELIEF',
#   'CUBA',
#   'AGENDA',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'DISPUTE SETTLEMENT',
#   'ARMED INCIDENTS',
#   'MILITARY OCCUPATION',
#   'ISRAEL',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'PALESTINE QUESTION',
#   'HUMAN RIGHTS',
#   'YUGOSLAVIA',
#   'CROATIA',
#   'BOSNIA AND HERZEGOVINA',
#   'THE FORMER YUGOSLAV REPUBLIC OF MACEDONIA',
#   'INTERNATIONAL CRIMINAL COURTS',
#   'INTERNATIONAL CRIMINAL JURISDICTION',
#   'WAR CRIMES',
#   'PRINCIPLES',
#   'TERMS OF REFERENCE',
#   'STATE SUCCESSION',
#   'YUGOSLAVIA',
#   'INTERNATIONAL CRIMINAL COURTS',
#   'INTERNATIONAL HUMANITARIAN LAW',
#   'INTERNATIONAL CRIMINAL JURISDICTION',
#   'WAR CRIMES',
#   'FORMER YUGOSLAVIA SITUATION',
#   'CROATIA SITUATION',
#   'THE FORMER YUGOSLAV REPUBLIC OF MACEDONIA',
#   'MEMBERS',
#   'ARMED INCIDENTS',
#   'CYPRUS',
#   'NICOSIA (CYPRUS)',
#   'PEACEKEEPING OPERATIONS',
#   'PEACEKEEPING OPERATIONS',
#   'ELECTION VERIFICATION',
#   'ANGOLA',
#   'ANGOLA SITUATION',
#   'FINANCING',
#   'BUDGET CONTRIBUTIONS',
#   'COSTS',
#   'STATE REPRESENTATION',
#   'STATE SUCCESSION',
#   'YUGOSLAVIA',
#   'BUDGET CONTRIBUTIONS',
#   'MEMBERS',
#   'PARTICIPANTS',
#   'UKRAINE',
#   'BUDGET CONTRIBUTIONS',
#   'PEACEKEEPING OPERATIONS',
#   'ARMED INCIDENTS',
#   'PEACEKEEPING OPERATIONS',
#   'CYPRUS',
#   'APPOINTMENT OF MEMBERS',
#   'HUMAN RIGHTS',
#   'SPECIAL MISSIONS',
#   'HAITI',
#   'FINANCIAL IMPLICATIONS',
#   'BUDGET',
#   'ELECTION OF MEMBERS',
#   'JUDGES',
#   'RULES OF PROCEDURE',
#   'MEMBERS',
#   'TERMS OF REFERENCE',
#   'TRANSNATIONAL CORPORATIONS',
#   'BUDGET',
#   'RECOMMENDATIONS',
#   'TOP ECHELON STAFF',
#   'ORGANIZATIONAL CHANGE',
#   'ORGANIZATIONAL STRUCTURE',
#   'RULES AND REGULATIONS',
#   'PROGRAMME PLANNING',
#   'PROGRAMME MANAGEMENT',
#   'PROGRAMME BUDGETING',
#   'COORDINATION WITHIN UN SYSTEM',
#   'MEDIUM-TERM PLAN',
#   'DECENTRALIZATION IN MANAGEMENT',
#   'REGIONAL COMMISSIONS',
#   'LOCATION OF OFFICES',
#   'GUIDELINES',
#   'FIELD OFFICES',
#   'COST EFFECTIVENESS',
#   'APPROPRIATIONS',
#   'PEACEKEEPING OPERATIONS',
#   'SCIENCE AND TECHNOLOGY',
#   'STATE SUCCESSION',
#   'STATE REPRESENTATION',
#   'YUGOSLAVIA',
#   'MEMBERS',
#   'PARTICIPANTS',
#   'GREEK CYPRIOT COMMUNITY',
#   'TURKISH CYPRIOT COMMUNITY',
#   'CYPRUS QUESTION',
#   'ARMED INCIDENTS',
#   'CYPRUS',
#   'CARGO SHIPS',
#   'TURKEY',
#   'HUMAN RIGHTS',
#   'BOSNIA AND HERZEGOVINA',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'ETHNIC CLEANSING',
#   'ARMED INCIDENTS',
#   'CYPRUS',
#   'TURKEY',
#   'SHIPS',
#   'DRUG TRAFFIC',
#   'ARMED INCIDENTS',
#   'CYPRUS',
#   'TURKEY',
#   'SHIPS',
#   'FREEDOM OF NAVIGATION',
#   'ELECTION OF MEMBERS',
#   'JUDGES',
#   'ELECTION OF MEMBERS',
#   'JUDGES',
#   'BIOGRAPHY',
#   'SERBS',
#   'BOSNIA AND HERZEGOVINA',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'ARMED INCIDENTS',
#   'BOSNIA AND HERZEGOVINA',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'PEACEKEEPING OPERATIONS',
#   'CYPRUS',
#   'CYPRUS QUESTION',
#   'TURKISH CYPRIOT COMMUNITY',
#   'SERBS',
#   'BOSNIA AND HERZEGOVINA',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'AMNESTY',
#   'EL SALVADOR',
#   'EL SALVADOR SITUATION',
#   'SANCTIONS',
#   'ECONOMIC ASSISTANCE',
#   'ERITREA',
#   'MEMBERS',
#   'CYPRUS QUESTION',
#   'TURKISH CYPRIOT COMMUNITY',
#   'GREEK CYPRIOT COMMUNITY',
#   'MONACO',
#   'MEMBERS',
#   'FOOD PROBLEMS',
#   'FOOD SECURITY',
#   'HUNGER',
#   'FOOD POLICY',
#   'TERMS OF REFERENCE',
#   'INSTITUTIONAL MACHINERY',
#   'SANCTIONS',
#   'FINANCIAL ASSISTANCE',
#   'COMPENSATION',
#   'ERITREA',
#   'MEMBERS',
#   'MONACO',
#   'MEMBERS',
#   'INTERNATIONAL CRIMINAL COURTS',
#   'INTERNATIONAL CRIMINAL JURISDICTION',
#   'FINANCING',
#   'JUDGES',
#   'ELECTION OF MEMBERS',
#   'AGENDA',
#   'POLITICAL CONDITIONS',
#   'GUATEMALA',
#   'DEPORTATION',
#   'ISRAEL',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'PALESTINIANS',
#   'HUMAN RIGHTS IN ARMED CONFLICTS',
#   'CIVILIAN PERSONS',
#   'NEGOTIATION',
#   'SERBS',
#   'ARMS EMBARGO',
#   'BOSNIA AND HERZEGOVINA',
#   'SANCTIONS',
#   'YUGOSLAVIA',
#   'HUMAN RIGHTS VIOLATIONS',
#   'ETHNIC CLEANSING',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'PALESTINIANS',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'SOCIAL CONDITIONS',
#   'ECONOMIC CONDITIONS',
#   'PALESTINE QUESTION',
#   'EXTRALEGAL EXECUTIONS',
#   'HUMAN RIGHTS',
#   'FREEDOM OF EXPRESSION',
#   'FREEDOM OF ASSOCIATION',
#   'FREEDOM OF THE PRESS',
#   'DETAINED PERSONS',
#   'DISAPPEARANCE OF PERSONS',
#   'ARMED FORCES',
#   'POLICE',
#   'MAPS',
#   'HAITI',
#   'AGENDA',
#   'APPOINTMENT OF OFFICIALS',
#   'SANCTIONS',
#   'YUGOSLAVIA',
#   'COMPENSATION',
#   'FINANCIAL ASSISTANCE',
#   'POLITICAL CONDITIONS',
#   'CONSTITUTIONS',
#   'HUMAN RIGHTS',
#   'GUATEMALA',
#   'BUDGET CONTRIBUTIONS',
#   'FINANCING',
#   'PREVENTIVE DIPLOMACY',
#   'FACT-FINDING MISSIONS',
#   'EARLY WARNING SYSTEMS',
#   'TRAINING PROGRAMMES',
#   'CONFIDENCE-BUILDING MEASURES',
#   'DISPUTE SETTLEMENT',
#   'STAFF SECURITY',
#   'DEMOCRACY',
#   'ELECTION VERIFICATION',
#   'HUMANITARIAN ASSISTANCE',
#   'PEACEKEEPING OPERATIONS',
#   'PEACEMAKING',
#   'PEACEBUILDING',
#   'COOPERATION BETWEEN ORGANIZATIONS',
#   'SANCTIONS',
#   'TRUST FUNDS',
#   'REGIONAL ORGANIZATIONS',
#   'FINANCIAL ASSISTANCE',
#   'FINANCING',
#   'AGENDA',
#   'PEACEKEEPING OPERATIONS',
#   'CROATIA',
#   'HUMANITARIAN ASSISTANCE',
#   'SAFE AREAS',
#   'SANCTIONS',
#   'BOSNIA AND HERZEGOVINA',
#   'THE FORMER YUGOSLAV REPUBLIC OF MACEDONIA',
#   'PREVENTIVE DIPLOMACY',
#   'CROATIA SITUATION',
#   'UNITED NATIONS PROTECTED AREAS',
#   'PEACEKEEPING OPERATIONS',
#   'MOZAMBIQUE',
#   'COSTS',
#   'FINANCING',
#   'BUDGET CONTRIBUTIONS',
#   'ARMAMENTS',
#   'LEGISLATIVE PROCESS',
#   'NICARAGUA',
#   'ON-SITE INSPECTION',
#   'TRUCE SUPERVISION',
#   'EL SALVADOR',
#   'ARMS TRANSFERS',
#   'CENTRAL AMERICA',
#   'WEAPONS DESTRUCTION',
#   'VERIFICATION',
#   'CENTRAL AMERICA SITUATION',
#   'ECONOMIC INTEGRATION',
#   'REGIONAL COOPERATION',
#   'ECONOMIC DEVELOPMENT',
#   'HUMAN RIGHTS',
#   'SOCIAL DEVELOPMENT',
#   'CENTRAL AMERICA',
#   'DISPUTE SETTLEMENT',
#   'CONSTITUTIONS',
#   'GUATEMALA',
#   'DECLARATIONS',
#   'DEMOCRACY',
#   'TRADE BOYCOTTS',
#   'TRADE POLICY',
#   'CYPRUS',
#   'CYPRUS QUESTION',
#   'GREEK CYPRIOT COMMUNITY',
#   'TURKISH CYPRIOT COMMUNITY',
#   'ANDORRA',
#   'MEMBERS',
#   'SPECIAL MISSIONS',
#   'NEGOTIATION',
#   'POLITICAL PARTIES',
#   'CONSTITUTIONS',
#   'SANCTIONS',
#   'HAITI',
#   'DISPUTE SETTLEMENT',
#   'SANCTIONS',
#   'POLITICAL CONDITIONS',
#   'HUMAN RIGHTS',
#   'DISPUTE SETTLEMENT',
#   'HAITI',
#   'HAITI QUESTION',
#   'ANDORRA',
#   'MEMBERS',
#   'POLITICAL STATUS',
#   'JAMMU AND KASHMIR',
#   'CEASEFIRES',
#   'HUMANITARIAN ASSISTANCE',
#   'SAFE AREAS',
#   'PEACEKEEPING OPERATIONS',
#   'BOSNIA AND HERZEGOVINA',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'PALESTINE QUESTION',
#   'MILITARY PERSONNEL',
#   'PROGRAMMES OF ACTION',
#   'SAFE AREAS',
#   'PEACEKEEPING OPERATIONS',
#   'BOSNIA AND HERZEGOVINA',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'NEGOTIATION',
#   'BOSNIA AND HERZEGOVINA',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'FINANCING',
#   'STAFFING',
#   'INTERNATIONAL CRIMINAL COURTS',
#   'HUMANITARIAN ASSISTANCE',
#   'PEACEKEEPING OPERATIONS',
#   'BOSNIA AND HERZEGOVINA',
#   'BOSNIA AND HERZEGOVINA SITUATION',
#   'MILITARY PERSONNEL',
#   'FINANCING',
#   'CAMBODIA',
#   'FINANCING',
#   'EL SALVADOR',
#   'FINANCING',
#   'SOMALIA',
#   'MOZAMBIQUE',
#   'FINANCING',
#   'PEACEKEEPING OPERATIONS',
#   'YUGOSLAVIA',
#   'BOSNIA AND HERZEGOVINA',
#   'CROATIA',
#   'THE FORMER YUGOSLAV REPUBLIC OF MACEDONIA',
#   'FINANCING',
#   'FINANCING',
#   'IRAQ',
#   'KUWAIT',
#   'ARMED INCIDENTS',
#   'MILITARY ACTIVITY',
#   'ISRAEL',
#   'LEBANON',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'CYPRUS',
#   'MEMBERS',
#   'CYPRUS QUESTION',
#   'PEACEKEEPING OPERATIONS',
#   'FINANCING',
#   'PURCHASING',
#   'ORGANIZATIONAL STRUCTURE',
#   'ORGANIZATIONAL CHANGE',
#   'ARMED INCIDENTS',
#   'MILITARY ACTIVITY',
#   'LEBANON',
#   'ISRAEL',
#   'ARMED INCIDENTS',
#   'CYPRUS',
#   'CYPRUS QUESTION',
#   'TURKISH CYPRIOT COMMUNITY',
#   'BOUNDARIES',
#   'ARMED INCIDENTS',
#   'SOVEREIGNTY',
#   'LEBANON',
#   'ISRAEL',
#   'ARMED INCIDENTS',
#   'DESTRUCTION OF PROPERTY',
#   'LEBANON',
#   'ISRAEL',
#   'SOVEREIGNTY',
#   'ARMED INCIDENTS',
#   'PALESTINIANS',
#   'LEBANON',
#   'ISRAEL',
#   'SPECIAL MISSIONS',
#   'ARMED FORCES',
#   'NICARAGUA',
#   'NEGOTIATION',
#   'CYPRUS',
#   'CYPRUS QUESTION',
#   'TURKISH CYPRIOT COMMUNITY',
#   'GREEK CYPRIOT COMMUNITY',
#   'LEGITIMACY OF GOVERNMENTS',
#   'MEMBERS',
#   'POPULATION COMPOSITION',
#   'CYPRUS',
#   'CYPRUS QUESTION',
#   'TURKISH CYPRIOT COMMUNITY',
#   'ERITREA',
#   'MONACO',
#   'MEMBERS',
#   'AGENDA',
#   'APPOINTMENT OF MEMBERS',
#   'MEMBERS',
#   'MEMBERS',
#   'APPOINTMENT OF MEMBERS',
#   'APPOINTMENT OF MEMBERS',
#   'MEMBERS',
#   'APPOINTMENT OF MEMBERS',
#   'MEMBERS',
#   'APPOINTMENT OF MEMBERS',
#   'MEMBERS',
#   'APPOINTMENT OF MEMBERS',
#   'NEGOTIATION',
#   'FOREIGN RELATIONS',
#   'BOUNDARIES',
#   'TREATIES',
#   'PAPUA NEW GUINEA',
#   'SOLOMON ISLANDS',
#   'SOCIAL POLICY',
#   'ISRAEL',
#   'STANDARD OF LIVING',
#   'PUBLIC WELFARE',
#   'PALESTINIANS',
#   'TERRITORIES OCCUPIED BY ISRAEL',
#   'HUMAN RIGHTS',
#   ...]}

# %%
import pandas as pd
outta = pd.DataFrame.from_dict(outspa,orient='index')
outta = outta.transpose()

# %%
outta.to_excel('dictspa.xlsx', engine='xlsxwriter')
